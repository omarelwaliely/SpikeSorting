# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
def splitColumns(datafile):
    df = pd.read_csv(datafile, delimiter='	')
    df.columns = ['first','second']
    return df['first'],df['second']
first, second = splitColumns("data.txt")

# %%
first
# Out:
# 0          7.370100e-06
# 1         -9.368400e-06
# 2         -1.659100e-05
# 3         -1.183000e-05
# 4         -1.696100e-06
#                ...
# 4417518    4.372900e-07
# 4417519    1.735100e-06
# 4417520   -6.696300e-07
# 4417521   -6.815500e-06
# 4417522   -9.699100e-06
# Name: first, Length: 4417523, dtype: float64

# %%
def extractFeatures(df,windowSize):
    featureList = []
    threshold = 3.5 * df[:499].std(axis=0)
    arr = df.to_numpy()
    i = 0
    while i < len(arr):
        if arr[i] > threshold:
            j = i
            maximum = arr[i]
            maxInd = i
            while(arr[j] > threshold):
                if arr[j] > maximum:
                    maximum = arr[j]
                    maxInd = j
                j+=1
                
            start = int(max(0, maxInd - windowSize // 2))
            end = int(min(len(arr), maxInd + windowSize // 2))
            
            window = arr[int(start):int(end)]
            std = np.std(window)
            diff = np.max(np.abs(np.diff(window)))
            maxPeak = np.max(window)
            minPeak = np.min(window)
            featureList.append({'std': std, 'diff': diff,'peakIndex' : maxInd, 'maxPeak': maxPeak, 'minPeak':minPeak })
            i = end
        else:
            i += 1
    featuresDF = pd.DataFrame(featureList)
    return featuresDF, threshold

# %%
def plotFeatures(features):
    X = features[['diff', 'std']]
    kmeans = KMeans(n_clusters=2)
    features['cluster'] = kmeans.fit_predict(X)
    plt.scatter(features['std'], features['diff'], c=features['cluster'], cmap='plasma')
    plt.xlabel('Standard Deviation')
    plt.ylabel('Maximum Difference Between Two Succesive Samples')
    plt.title('K-Means Visualization')
    plt.show()
    return features

# %%
windowSize = 0.002 * 24414
windowSize = int(windowSize)
first = pd.DataFrame()
second = pd.DataFrame()
first, second = splitColumns("Data.txt")
features1, threshold = extractFeatures(first,windowSize)
features2, threshold2 = extractFeatures(second,windowSize)
features1 = plotFeatures(features1)
features2 = plotFeatures(features2)
features1.to_csv("features1.csv",index = False)
features2.to_csv("features2.csv", index = False)

# %%
first
# Out:
# 0          7.370100e-06
# 1         -9.368400e-06
# 2         -1.659100e-05
# 3         -1.183000e-05
# 4         -1.696100e-06
#                ...
# 4417518    4.372900e-07
# 4417519    1.735100e-06
# 4417520   -6.696300e-07
# 4417521   -6.815500e-06
# 4417522   -9.699100e-06
# Name: first, Length: 4417523, dtype: float64

# %%
features1
# Out:
#            std      diff  peakIndex   maxPeak   minPeak  cluster
# 0     0.000015  0.000028        745  0.000037 -0.000031        1
# 1     0.000011  0.000019       1226  0.000030 -0.000019        1
# 2     0.000025  0.000054       1793  0.000072 -0.000063        0
# 3     0.000014  0.000016       2025  0.000038 -0.000020        1
# 4     0.000015  0.000018       3236  0.000033 -0.000034        1
# ...        ...       ...        ...       ...       ...      ...
# 4518  0.000011  0.000023    4416143  0.000037 -0.000029        1
# 4519  0.000020  0.000048    4416708  0.000054 -0.000058        0
# 4520  0.000014  0.000017    4416735  0.000031 -0.000038        1
# 4521  0.000024  0.000051    4416937  0.000066 -0.000060        0
# 4522  0.000011  0.000023    4417346  0.000036 -0.000016        1
#
# [4523 rows x 6 columns]

# %%
first[features1[features1["cluster"] == 0]["peakIndex"][2]-20:features1[features1["cluster"] == 0]["peakIndex"][2]+20]
# Out:
# 1773   -3.049800e-06
# 1774    3.357800e-06
# 1775    1.536100e-06
# 1776   -5.776800e-06
# 1777   -1.053400e-05
# 1778   -7.548900e-06
# 1779   -1.186900e-07
# 1780    3.774300e-06
# 1781    1.001200e-06
# 1782   -2.877300e-06
# 1783   -4.250200e-07
# 1784    8.391900e-06
# 1785    1.425200e-05
# 1786    5.041200e-06
# 1787   -2.261100e-05
# 1788   -5.415400e-05
# 1789   -6.298600e-05
# 1790   -3.354300e-05
# 1791    2.006700e-05
# 1792    6.331000e-05
# 1793    7.187700e-05
# 1794    5.195700e-05
# 1795    2.894700e-05
# 1796    1.879900e-05
# 1797    1.519200e-05
# 1798    4.090100e-06
# 1799   -1.635200e-05
# 1800   -3.423300e-05
# 1801   -3.832500e-05
# 1802   -2.979800e-05
# 1803   -1.948700e-05
# 1804   -1.527900e-05
# 1805   -1.488000e-05
# 1806   -1.251600e-05
# 1807   -8.754600e-06
# 1808   -8.274400e-06
# 1809   -1.017800e-05
# 1810   -7.940600e-06
# 1811    1.246500e-07
# 1812    7.277200e-06
# Name: first, dtype: float64

# %%
allSpikes1 = []
for ind in features1[features1["cluster"] == 0]["peakIndex"]:
    start = ind - 20
    end = ind + 20
    allSpikes1.append([first[start:end]])
allSpikes2 = []
for ind in features1[features1["cluster"] == 1]["peakIndex"]:
    start = ind - 20
    end = ind + 20
    allSpikes2.append([first[start:end]])
allSpikes3 = []
for ind in features2[features2["cluster"] == 0]["peakIndex"]:
    start = ind - 20
    end = ind + 20
    allSpikes3.append([second[start:end]])
allSpikes4 = []
for ind in features2[features2["cluster"] == 1]["peakIndex"]:
    start = ind - 20
    end = ind + 20
    allSpikes4.append([second[start:end]])

# %%
avg_spikes1 = []
avg_spikes1.append(np.average(allSpikes1, axis = 0)[0])
avg_spikes1.append(np.average(allSpikes2, axis = 0)[0])
avg_spikes2 = []
avg_spikes2.append(np.average(allSpikes3, axis = 0)[0])
avg_spikes2.append(np.average(allSpikes4, axis = 0)[0])

# %%
avg_spikes1
# Out:
# [array([-1.95943896e-07, -3.59001742e-07, -4.53581549e-07, -3.53772295e-07,
#         -2.05312600e-07, -2.69503005e-07, -5.46050791e-07, -7.11000838e-07,
#         -4.94544104e-07,  9.01504488e-08,  1.22874127e-06,  3.64941248e-06,
#          6.79118854e-06,  5.61273301e-06, -7.42350279e-06, -3.14051307e-05,
#         -4.87937167e-05, -3.74652284e-05,  3.79285061e-06,  4.81537047e-05,
#          6.57193686e-05,  5.21375256e-05,  2.74129478e-05,  1.06657059e-05,
#          3.56047024e-06, -2.55916737e-06, -1.16711418e-05, -1.97013311e-05,
#         -2.23357092e-05, -2.07385374e-05, -1.88814190e-05, -1.83141321e-05,
#         -1.74555246e-05, -1.48310610e-05, -1.10967361e-05, -7.77512911e-06,
#         -5.29846408e-06, -2.98777740e-06, -3.71644696e-07,  2.20287778e-06]),
#  array([-5.17906917e-06, -5.45342126e-06, -5.40118727e-06, -4.84891076e-06,
#         -4.14667355e-06, -3.87844072e-06, -4.02185467e-06, -3.78602684e-06,
#         -2.70610081e-06, -1.64515105e-06, -1.94353903e-06, -3.36337937e-06,
#         -3.79940333e-06, -2.00637613e-06,  6.39168113e-08, -3.87121981e-07,
#         -1.88597832e-06,  1.62516955e-06,  1.35864627e-05,  2.83738491e-05,
#          3.51070914e-05,  2.87221297e-05,  1.53151817e-05,  5.36085233e-06,
#          3.17915569e-06,  4.68431828e-06,  4.25507836e-06,  1.08205262e-06,
#         -1.80780877e-06, -2.50986190e-06, -2.21805899e-06, -2.83533965e-06,
#         -4.42945061e-06, -5.65161691e-06, -5.74574552e-06, -5.28048312e-06,
#         -5.11714048e-06, -5.36895627e-06, -5.56896264e-06, -5.44182921e-06])]

# %%
avg_spikes1
# Out:
# [array([-1.95943896e-07, -3.59001742e-07, -4.53581549e-07, -3.53772295e-07,
#         -2.05312600e-07, -2.69503005e-07, -5.46050791e-07, -7.11000838e-07,
#         -4.94544104e-07,  9.01504488e-08,  1.22874127e-06,  3.64941248e-06,
#          6.79118854e-06,  5.61273301e-06, -7.42350279e-06, -3.14051307e-05,
#         -4.87937167e-05, -3.74652284e-05,  3.79285061e-06,  4.81537047e-05,
#          6.57193686e-05,  5.21375256e-05,  2.74129478e-05,  1.06657059e-05,
#          3.56047024e-06, -2.55916737e-06, -1.16711418e-05, -1.97013311e-05,
#         -2.23357092e-05, -2.07385374e-05, -1.88814190e-05, -1.83141321e-05,
#         -1.74555246e-05, -1.48310610e-05, -1.10967361e-05, -7.77512911e-06,
#         -5.29846408e-06, -2.98777740e-06, -3.71644696e-07,  2.20287778e-06]),
#  array([-5.17906917e-06, -5.45342126e-06, -5.40118727e-06, -4.84891076e-06,
#         -4.14667355e-06, -3.87844072e-06, -4.02185467e-06, -3.78602684e-06,
#         -2.70610081e-06, -1.64515105e-06, -1.94353903e-06, -3.36337937e-06,
#         -3.79940333e-06, -2.00637613e-06,  6.39168113e-08, -3.87121981e-07,
#         -1.88597832e-06,  1.62516955e-06,  1.35864627e-05,  2.83738491e-05,
#          3.51070914e-05,  2.87221297e-05,  1.53151817e-05,  5.36085233e-06,
#          3.17915569e-06,  4.68431828e-06,  4.25507836e-06,  1.08205262e-06,
#         -1.80780877e-06, -2.50986190e-06, -2.21805899e-06, -2.83533965e-06,
#         -4.42945061e-06, -5.65161691e-06, -5.74574552e-06, -5.28048312e-06,
#         -5.11714048e-06, -5.36895627e-06, -5.56896264e-06, -5.44182921e-06])]

# %%
time_points = np.arange(len(avg_spikes))
indices = np.arange(len(avg_spikes1[0]))
plt.plot(indices, avg_spikes1[0], color='blue', label="neuron one")
plt.plot(indices, avg_spikes1[1], color='red', label="neuron two")
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Single Spike Waveform')
plt.legend()

plt.grid(True)
plt.show()

# %%
time_points = np.arange(len(avg_spikes))
indices = np.arange(len(avg_spikes2[0]))
plt.plot(indices, avg_spikes2[0], color='blue', label="neuron one")
plt.plot(indices, avg_spikes2[1], color='red', label="neuron two")
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Single Spike Waveform')
plt.grid(True)
plt.legend()

plt.show()
